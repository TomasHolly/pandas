# %%
import pandas as pd

# %%
df1 = pd.DataFrame(
    data = {
        "first":[1,1,1,1],
        "second":[1,1,1,1],
        "third":[1,2,1,2],
               
    }, index= [1,2,3,4])

df2 = pd.DataFrame(
    data = {
        "first":[2,2,2,2],
        "second":[2,2,2,2],
        "fourth":[1,3,1,3],
        
    },index = [3,4,5,6])

# %%
df1
# Out:
#    first  second  third
# 1      1       1      1
# 2      1       1      2
# 3      1       1      1
# 4      1       1      2

# %%
df2
# Out:
#    first  second  fourth
# 3      2       2       1
# 4      2       2       3
# 5      2       2       1
# 6      2       2       3

# %%
pd.concat([df1,df2], join="outer", axis = 0)
# Out:
#    first  second  third  fourth
# 1      1       1    1.0     NaN
# 2      1       1    2.0     NaN
# 3      1       1    1.0     NaN
# 4      1       1    2.0     NaN
# 3      2       2    NaN     1.0
# 4      2       2    NaN     3.0
# 5      2       2    NaN     1.0
# 6      2       2    NaN     3.0

# %%
df1 = pd.DataFrame(data = {"a": [1,2,1,2,1,2], "b": [3,4,3,4,3,4]})
df2 = pd.DataFrame(data = {"a": [1,3,1,3,1], "b": [5,4,5,4,5]})

# %%
df1
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 2  1  3
# 3  2  4
# 4  1  3
# 5  2  4

# %%
df2
# Out:
#    a  b
# 0  1  5
# 1  3  4
# 2  1  5
# 3  3  4
# 4  1  5

# %%
df = pd.concat([df1,df2], axis = 0)
df
# Out:
#    a  b
# 0  1  3
# 1  2  4
# 2  1  3
# 3  2  4
# 4  1  3
# 5  2  4
# 0  1  5
# 1  3  4
# 2  1  5
# 3  3  4
# 4  1  5

# %%
df.reset_index(drop= 1, inplace =Tru)
